# %%
import matplotlib.pyplot as plt
import numpy as np
# !pip install seaborn
import seaborn as sns

# Apply Seaborn style globally
sns.set_theme(style="whitegrid")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
"""
Special/ImageComparison/krn/flip/854x480
                        time:   [43.799 µs 45.921 µs 48.488 µs]
Special/ImageComparison/img/flip/854x480
                        time:   [438.57 µs 438.61 µs 438.66 µs]
Special/ImageComparison/krn/resize_oversample/854x480
                        time:   [23.196 ms 23.472 ms 23.777 ms]
Special/ImageComparison/img/resize_oversample/854x480
                        time:   [312.52 ms 314.45 ms 316.68 ms]
Special/ImageComparison/krn/resize_undersample/854x480
                        time:   [344.31 µs 351.58 µs 360.32 µs]
Special/ImageComparison/img/resize_undersample/854x480
                        time:   [3.5177 ms 3.5737 ms 3.6364 ms]
Special/ImageComparison/krn/rgb2gray/854x480
                        time:   [50.759 µs 53.015 µs 55.867 µs]
Special/ImageComparison/img/rgb2gray/854x480
                        time:   [1.0862 ms 1.0870 ms 1.0880 ms]
Special/ImageComparison/krn/flip/1280x720
                        time:   [70.175 µs 71.583 µs 73.155 µs]
Special/ImageComparison/img/flip/1280x720
                        time:   [982.86 µs 983.06 µs 983.32 µs]
Special/ImageComparison/krn/resize_oversample/1280x720
                        time:   [22.876 ms 23.171 ms 23.523 ms]
Special/ImageComparison/img/resize_oversample/1280x720
                        time:   [470.81 ms 481.85 ms 493.54 ms]
Special/ImageComparison/krn/resize_undersample/1280x720
                        time:   [316.75 µs 333.03 µs 351.74 µs]
Special/ImageComparison/img/resize_undersample/1280x720
                        time:   [4.3188 ms 4.4495 ms 4.5936 ms]
Special/ImageComparison/krn/rgb2gray/1280x720
                        time:   [112.23 µs 127.15 µs 143.05 µs]
Special/ImageComparison/img/rgb2gray/1280x720
                        time:   [2.4455 ms 2.4485 ms 2.4534 ms]
Special/ImageComparison/krn/flip/1920x1080
                        time:   [173.83 µs 190.38 µs 208.12 µs]
Special/ImageComparison/img/flip/1920x1080
                        time:   [2.2106 ms 2.2114 ms 2.2124 ms]
Special/ImageComparison/krn/resize_oversample/1920x1080
                        time:   [23.719 ms 24.046 ms 24.408 ms]
Special/ImageComparison/img/resize_oversample/1920x1080
                        time:   [490.99 ms 497.35 ms 503.56 ms]
Special/ImageComparison/krn/resize_undersample/1920x1080
                        time:   [331.14 µs 341.60 µs 353.79 µs]
Special/ImageComparison/img/resize_undersample/1920x1080
                        time:   [5.7674 ms 5.9539 ms 6.1508 ms]
Special/ImageComparison/krn/rgb2gray/1920x1080
                        time:   [211.66 µs 223.53 µs 237.32 µs]
Special/ImageComparison/img/rgb2gray/1920x1080
                        time:   [5.5393 ms 5.5556 ms 5.5764 ms]
Special/ImageComparison/krn/flip/2560x1440
                        time:   [231.06 µs 239.24 µs 248.22 µs]
Special/ImageComparison/img/flip/2560x1440
                        time:   [3.9514 ms 3.9704 ms 3.9932 ms]
Special/ImageComparison/krn/resize_oversample/2560x1440
                        time:   [23.525 ms 23.853 ms 24.212 ms]
Special/ImageComparison/img/resize_oversample/2560x1440
                        time:   [1.0263 s 1.0329 s 1.0398 s]
Special/ImageComparison/krn/resize_undersample/2560x1440
                        time:   [316.41 µs 320.49 µs 325.03 µs]
Special/ImageComparison/img/resize_undersample/2560x1440
                        time:   [6.7623 ms 6.8021 ms 6.8477 ms]
Special/ImageComparison/krn/rgb2gray/2560x1440
                        time:   [280.99 µs 289.24 µs 298.28 µs]
Special/ImageComparison/img/rgb2gray/2560x1440
                        time:   [9.8184 ms 9.8228 ms 9.8271 ms]
Special/ImageComparison/krn/flip/3840x2160
                        time:   [727.47 µs 732.95 µs 739.18 µs]
Special/ImageComparison/img/flip/3840x2160
                        time:   [8.8176 ms 8.8207 ms 8.8249 ms]
Special/ImageComparison/krn/resize_oversample/3840x2160
                        time:   [22.772 ms 23.062 ms 23.449 ms]
Special/ImageComparison/img/resize_oversample/3840x2160
                        time:   [1.1603 s 1.1636 s 1.1666 s]
Special/ImageComparison/krn/resize_undersample/3840x2160
                        time:   [353.88 µs 364.91 µs 377.11 µs]
Special/ImageComparison/img/resize_undersample/3840x2160
                        time:   [10.496 ms 10.565 ms 10.640 ms]
Special/ImageComparison/krn/rgb2gray/3840x2160
                        time:   [607.04 µs 610.85 µs 615.02 µs]
Special/ImageComparison/img/rgb2gray/3840x2160
                        time:   [22.287 ms 22.328 ms 22.376 ms]

                        ------

                        average time

Special/ImageComparison/krn/flip/854x480                               45.921
Special/ImageComparison/krn/flip/1280x720                              71.583
Special/ImageComparison/krn/flip/1920x1080                               190.38
Special/ImageComparison/krn/flip/2560x1440                               239.24
Special/ImageComparison/krn/flip/3840x2160                               732.95
Special/ImageComparison/krn/resize_oversample/854x480                              23472.
Special/ImageComparison/krn/resize_oversample/1280x720                               23171.
Special/ImageComparison/krn/resize_oversample/1920x1080                              24046.
Special/ImageComparison/krn/resize_oversample/2560x1440                              23853.
Special/ImageComparison/krn/resize_oversample/3840x2160                              23062.
Special/ImageComparison/krn/resize_undersample/854x480                               351.58
Special/ImageComparison/krn/resize_undersample/1280x720                              333.03
Special/ImageComparison/krn/resize_undersample/1920x1080                               341.60
Special/ImageComparison/krn/resize_undersample/2560x1440                               320.49
Special/ImageComparison/krn/resize_undersample/3840x2160                               364.91
Special/ImageComparison/krn/rgb2gray/854x480                               53.015
Special/ImageComparison/krn/rgb2gray/1280x720                              127.15
Special/ImageComparison/krn/rgb2gray/1920x1080                               223.53
Special/ImageComparison/krn/rgb2gray/2560x1440                               289.24
Special/ImageComparison/krn/rgb2gray/3840x2160                               610.85

Special/ImageComparison/img/flip/854x480                               438.61
Special/ImageComparison/img/flip/1280x720                              983.06
Special/ImageComparison/img/flip/1920x1080                               2211.4
Special/ImageComparison/img/flip/2560x1440                               3970.4
Special/ImageComparison/img/flip/3840x2160                               8820.7
Special/ImageComparison/img/resize_oversample/854x480                              314450.
Special/ImageComparison/img/resize_oversample/1280x720                               481850.
Special/ImageComparison/img/resize_oversample/1920x1080                              497350.
Special/ImageComparison/img/resize_oversample/2560x1440                              1032900
Special/ImageComparison/img/resize_oversample/3840x2160                              1163600
Special/ImageComparison/img/resize_undersample/854x480                               3573.7
Special/ImageComparison/img/resize_undersample/1280x720                              4449.5
Special/ImageComparison/img/resize_undersample/1920x1080                               5953.9
Special/ImageComparison/img/resize_undersample/2560x1440                               6802.1
Special/ImageComparison/img/resize_undersample/3840x2160                               10565.
Special/ImageComparison/img/rgb2gray/854x480                               1087.0
Special/ImageComparison/img/rgb2gray/1280x720                              2448.5
Special/ImageComparison/img/rgb2gray/1920x1080                               5555.6
Special/ImageComparison/img/rgb2gray/2560x1440                               9822.8
Special/ImageComparison/img/rgb2gray/3840x2160                               22328
"""

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))  # 2x2 grid

# Flatten the axes array for easy iteration
axes = axes.flatten()

labels = ["480p", "720p", "1080p", "1440p", "4k"]
titles = ["Horizontal Flip (u8)", "Resize Oversample (f32/u8)", "Resize Undersample (f32/u8)", "RGB -> Gray (u8)"]
kornia_t = [
[45.921,
71.583,
190.38,
239.24,
732.95],
[23472.,
23171.,
24046.,
23853.,
23062.],
[351.58,
333.03,
341.60,
320.49,
364.91],
[53.015,
127.15,
223.53,
289.24,
610.85],
]
image_t = [
[438.61,
983.06,
2211.4,
3970.4,
8820.7],
[314450.,
481850.,
497350.,
1032900,
1163600],
[3573.7,
4449.5,
5953.9,
6802.1,
10565.],
[1087.0,
2448.5,
5555.6,
9822.8,
22328],
]




for i in range(4):
    # Sample data
    # from benchmark
    kornia_times = kornia_t[i]
    image_times = image_t[i]

    x = np.arange(len(labels))  # label locations
    width = 0.2  # width of the bars

    # Plotting the bars
    rects1 = axes[i].bar(x - width/2, kornia_times, width, label='Kornia')
    rects2 = axes[i].bar(x + width/2, image_times, width, label='Image')

    # Add labels, title and custom x-axis tick labels
    axes[i].set_xlabel('Resolution')
    axes[i].set_ylabel('Processing Time (µs)')
    axes[i].set_title(titles[i])
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(labels, rotation=30, ha='right')
    axes[i].legend()

    # Optional: add value labels on bars
    for rect in rects1 + rects2:
        height = rect.get_height()
        axes[i].annotate(f'{height:.1f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # offset text upward
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.suptitle("Kornia vs Image (RGB, CPU, Intel i7-13700H)", fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.9)  # Leave room for suptitle
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 4 operations => 4 subplots
fig, axes = plt.subplots(2, 2, figsize=(8, 8))

# Sample data
# from benchmark
labels = ["480p", "720p", "1080p", "1440p", "4k"]
kornia_times = [142.35, 286.58, 752.17]
image_times = [2212.5, 3940.6, 9051.7]

x = np.arange(len(labels))  # label locations
width = 0.2  # width of the bars

fig, ax = plt.subplots(figsize=(8, 6))

# Plotting the bars
rects1 = ax.bar(x - width/2, kornia_times, width, label='Kornia')
rects2 = ax.bar(x + width/2, image_times, width, label='Image')

# Add labels, title and custom x-axis tick labels
ax.set_xlabel('Resolution')
ax.set_ylabel('Processing Time (µs)')
ax.set_title('Horizontal Flip (u8, RGB, CPU, Intel i7-13700H)')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=30, ha='right')
ax.legend()

# Optional: add value labels on bars
for rect in rects1 + rects2:
    height = rect.get_height()
    ax.annotate(f'{height:.1f}',
                xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3),  # offset text upward
                textcoords="offset points",
                ha='center', va='bottom')

plt.tight_layout()
plt.show()
